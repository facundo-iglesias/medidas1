# %% [markdown]
# # Universidad Tecnológica Nacional
# ## Facultad Regional Buenos Aires
#
# ---
#
# ### Informe de Laboratorio 2 - Error sistemático de método
#
# #### Asignatura: Medidas Electrónicas I
# #### Curso: R4052
# #### Fecha: 06/06/2023
#
# ---
#
# #### Estudiantes:
# - Dalinger, Fabio Ezequiel
# - Iglesias, Facundo Nahuel
# - Orona, Facundo
# - Rios, Tamara Julieta
# - Trotta, Guillermo
#
# ---
#
# #### Profesores responsables:
# - Ing. Marinsek, Emiliano
# - Ing. Perdomo, Juan Manuel
#
# ---
#
# #### Grupo 1
#
#
# ---

# %% [markdown]
# ## Objetivos:
# En la siguiente práctica se tiene como objetivo obtener la tensión de salida de un divisor de tensión resistivo, causando un error de método al empeorar artificialmente la resistencia voltimétrica del instrumento de sensor.  Para ellos se utilizarán 2 errores de método diferentes:
#
# 1) Error de método despreciable
#
# 2)	Error de método del 20%
#
# ## Procedimiento especifico de la medición:
#
# #### Fundamentos teóricos:
# El error se define como la diferencia entre el valor verdadero (Vv) y el valor indicado de la magnitud a medir (Vi). Los errores se pueden clasificar en dos grandes grupos: errores sistemáticos y errores aleatorios.
# * Se denomina error aleatorio a aquellos que se deben a las pequeñas variaciones que aparecen entre observaciones sucesivas realizadas por el mismo observador y bajo las mismas condiciones.
# * Se denomina error sistemático a aquel que es constante a lo largo de todo el proceso de medida y, por tanto, afecta a todas las medidas de un modo definido y es el mismo para todas ellas. Estos errores tienen siempre un signo determinado y las causas probables pueden ser: Errores instrumentales, Error del observador y Errores de método de medida.
# En la práctica se analizará el error sistemático de método, que es la componente del error de medición que se produce debió al método de medición. Se caracteriza principalmente debido a que el método de medición altera el sistema a medir:
# •	Absorción de energía
# •	Desadaptación de impedancias
# El error de método se calcula de la siguiente manera:
#
# \begin{equation}
# e_{MR}=\frac{V_1-V_V}{V_V}
# \end{equation}
#
# #### Instrumental utilizado:
#
# * Multímetro genérico de los estudiantes
# * Fuente regulable de tensión simple del laboratorio
# * Resistencia regulable del Laboratorio y/o Potenciómetros/Resistencias de los estudiantes
#
#
# ![circuito](https://drive.google.com/uc?id=1BK-LRLlI9ZhxvEl2D3dA_3Yq2crmRNxV)
#
# Referencias:
# * VF : Tensión de la fuente de alimentación
# * RA y RB : Resistores del divisor de tensión
# * RF : Resistencia interna de la fuente de alimentación
# * RV : Resistencia interna del Instrumento de medición
# * V : Indicación del multímetro

# %% [markdown]
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# #### a)	Se pide obtener el error de método despreciable para lo cual se utilizaron los siguientes valores de resistencias:
#
# | RESISTOR    | VALOR[Ω]    |
# |-------------|-------      |
# | Ra          | 10000       |
# | Rb          | 100         |
# | Rf          | 1           |
# | Rv          | 1000000     |
#
# Se observa que las mediciones efectuadas en condiciones de repetitibilidad permanecen estables.
#
# |Indice       |Tension de fuente |Tension sobre resistor |
# |-------------|--------------|---------------------------|
# |1	|9,9	|0,099|
# |2	|9,9	|0,099|
# |3	|9,9	|0,099|
# |4	|9,9	|0,099|
# |5	|9,9	|0,099|
# |6	|9,9	|0,099|
# |7	|9,9	|0,099|
# |8	|9,9	|0,099|
# |9	|9,9	|0,099|
# |10	|9,9	|0,099|
#
# \begin{equation}
# V{ind}= 0,099 V
# \end{equation}
#
# Aplicando Thevenin al circuito original, obtenemos el siguiente circuito:
#
# ![thevenin](https://drive.google.com/uc?id=1KlsxudYHgsZ0Kv5wOWeIo4MSOEBgelR5)
#
# Resistencia de Thevenin:
# \begin{equation}
# R_{th} = \frac{(R_F+R_A)*R_B}{(R_F+R_A)+R_B}
# \end{equation}
#
#
# \begin{equation}
# R_{th} = \frac{(1\Omega+10k\Omega)*100\Omega}{(1\Omega+10k\Omega)+100\Omega}
# \end{equation}
#
#
# \begin{equation}
# R_{th} = 99,00999901\Omega
# \end{equation}
#
# Error de método:
# \begin{equation}
# e_{MR}=\frac{V_1-V_V}{V_V} = \frac{V_{RV}-V_{th}}{V_{th}} = \frac{V_{RV}}{V{th}}-1 = \frac{R_V}{R_{th}+R_V}-1
# \end{equation}
#
# \begin{equation}
# e_{MR}= \frac{R_V}{R_{th}+R_V} - \frac{R_{th}+R_V}{R_{th}+R_V}
# \end{equation}
#
#
# \begin{equation}
# e_{MR}= \frac{-R_{th}}{R_{th}+R_V}
# \end{equation}
#
#
# \begin{equation}
# e_{MR}= \frac{-99,00999901\Omega}{99,00999901\Omega+1M\Omega}
# \end{equation}
#
#
# \begin{equation}
# \boxed{e_{MR}= -0,000099}
# \end{equation}
#
#
#
# Error de método porcenutal:
# \begin{equation}
# e_{MR\%} = 0,000099x100 = 0,009900019 \%
# \end{equation}
#
#
# \begin{equation}
# \boxed{e_{MR\%} = 0,009900019 \%}
# \end{equation}
#
#
# El error de método dio como resultado un número menor a cero, lo cual indica que lo que se mide es por defecto. El valor indicado es mucho menor que el verdadero.
#
# ### Cálculo de la incertidumbre expandida
#
# Valor medido: 0,099V
#
# Cuentas totales: 99c
#
# Se obtuvieron del manual del voltimetro los siguientes datos de exactitud:
# * Rango: 200 mV
# * Error de lectura: 0,7%
# * Error de cuenta: 3c
#
# Incertidumbre tipo B:
# \begin{equation}
# u_B = (\frac{0,7\%}{100\%}+\frac{3c}{99c})*\frac{0,099V}{\sqrt{3}}
# \end{equation}
#
# \begin{equation}
# u_B = 0,0021321 V
# \end{equation}
#
# Como la medición de tensión se mantuvo estable en todas las mediciones la incertidumbre tipo A resulta nula, siendo la incertumbre tipo B dominante:
#
# \begin{equation}
# Relación = \frac{u_N}{u_R} = \frac{0}{ 0,0021321} =  0   \rightarrow K(0) = 1,65
# \end{equation}
#
# La incertidumbre expandida resulta:
#
# \begin{equation}
# U_{exp} = K * u_B = 1,65 * 0,0021321 V
# \end{equation}
#
# \begin{equation}
# \boxed{U_{exp} = 0,0035179 V}
# \end{equation}
#
#
# #### Corrección
#
# Se debe corregir el valor indicado si:
# \begin{equation}
#  |e_m| > \frac{U_{exp}}{10}
# \end{equation}
#
# \begin{equation}
#  0,000099 >  0,00035179 V
# \end{equation}
#
# No resulta necesario corregir y el valor indicado es:
#
# \begin{equation}
#  \boxed{0,099 V +- 0,0035179 V}
# \end{equation}
# Para un intervalo de confianza del 95,45%

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### b)	Se pide obtener el error de método del 20% para lo cual se utilizaron los siguientes valores de resistencias:
#
# | RESISTOR    | VALOR[Ω]    |
# |-------------|-------      |
# | Ra          | 10000       |
# | Rb          | 100         |
# | Rf          | 1           |
# | Rv          | 330           |
#
# Se utilizó un resistor de 330 ohm en paralelo a la resistencia interna del voltimetro para empeorar el error de método.
#
# Se realizaron las siguientes mediciones de tensión sobre el resistor:
#
# |MEDICIÓN   |TENSIÓN SOBRE EL RESISTOR|
# |-----|-----|
# |1	|0,066|
# |2	|0,066|
# |3	|0,066|
# |4	|0,066|
# |5	|0,066|
# |6	|0,066|
# |7	|0,066|
# |8	|0,066|
# |9	|0,066|
# |10	|0,066|
#
# \begin{equation}
# V_{IND} = 0,066V
# \end{equation}
#
#
# Aplicando Thevenin al circuito original, tal como se hizo en el punto anterior:
# Resistencia de Thevenin (RTH):
#
# Resistencia de Thevenin (RTH):
# \begin{equation}
# R_{th} = \frac{(R_F+R_A)*R_B}{(R_F+R_A)+R_B}
# \end{equation}
#
#
# \begin{equation}
# R_{th} = \frac{(1\Omega+10k\Omega)*100\Omega}{(1\Omega+10k\Omega)+100\Omega}
# \end{equation}
#
#
# \begin{equation}
# R_{th} = 99,00999901 \Omega
# \end{equation}
#
#
# Error de método:
# \begin{equation}
# e_{MR}= \frac{-R_{th}}{R_{th}+R_V}
# \end{equation}
#
#
# \begin{equation}
# e_{MR}= \frac{-99,00999901 \Omega}{99,00999901 \Omega+330\Omega}
# \end{equation}
#
#
# \begin{equation}
# \boxed{e_{MR}= 0,2307871594}
# \end{equation}
#
# Error de método porcentual:
#
# \begin{equation}
# \boxed{e_{MR\%}= 23,07871594\%}
# \end{equation}
#
# El error de método dio como resultado un número menor a cero, lo cual indica que lo que se mide es por defecto. El valor indicado es mucho menor que el verdadero.
#
# ### Cálculo de la incertidumbre expandida
#
# Valor medido: 0,066V
#
# Cuentas totales: 66c
#
# Se obtuvieron del manual del voltimetro los siguientes datos de exactitud:
# * Rango: 200 mV
# * Error de lectura: 0,7%
# * Error de cuenta: 3c
#
# Incertidumbre tipo B:
# \begin{equation}
# u_B = (\frac{0,7\%}{100\%}+\frac{3c}{66c})*\frac{0,066V}{\sqrt{3}}
# \end{equation}
#
# \begin{equation}
# u_B = 0,019987 V
# \end{equation}
#
# Como la medición de tensión se mantuvo estable en todas las mediciones la incertidumbre tipo A resulta nula, siendo la incertumbre tipo B dominante:
#
# \begin{equation}
# Relación = \frac{u_N}{u_R} = \frac{0}{ 0,019987} =  0   \rightarrow K(0) = 1,65
# \end{equation}
#
# La incertidumbre expandida resulta:
#
# \begin{equation}
# U_{exp} = K * u_B = 1,65 * 0,019987 V = 0,032978 V
# \end{equation}
#
# \begin{equation}
# \boxed{U_{exp} = 0,032978 V}
# \end{equation}
#
#
# #### Corrección
#
# Se debe corregir el valor indicado si:
# \begin{equation}
#  |e_m| > \frac{U_{exp}}{10}
# \end{equation}
#
# \begin{equation}
#   0,2307871594 >  0,0032978 V
# \end{equation}
#
# Se debe corregir:
#
# \begin{equation}
#   V{verdadero} = V_{IND}* \frac{1}{1+e_M}
# \end{equation}
#
# \begin{equation}
#   V{verdadero} = 0,066* \frac{1}{1-0,2307871594}
# \end{equation}
#
#
# \begin{equation}
# \boxed{0,0858 V +- 0,032978 V}
# \end{equation}
# Para un intervalo de confianza del 95,45%

# %% [markdown]
# ### Conclusiones
#
# Se observa que en el primer caso la medición no resulta afectada de forma notable debido al valor elevado (10Mohm) de la impedancia interna del voltimero, la cual no permite que circule corriente a traves del instrumento alterando la medición y por lo tanto no resulta necesario corregir el valor medido.
#
# En el segundo caso se impone una condición en la cual se fuerza a que la impedancia interna del voltimetro tenga un valor menor, esto se logra agregando una resistencia en paralelo de un valor de 330ohm. Por lo tanto, se simula un consumo de energía mayor y como consecuencia el error de método deja de ser despreciable. En esta condición, se requiere realizar una corrección sobre el valor medido.
